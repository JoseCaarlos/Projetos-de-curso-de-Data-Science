# %% [markdown]
# # Visão Computacional e Deep Learning

# %% [markdown]
# #### Instalando a biblioteca Pillow

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in d:\desenvolvimento\anaconda\lib\site-packages (6.2.0)

# %%
import PIL

# %% [markdown]
# #### Verificando as versões instaladas

# %%
print('Pillow Version:', PIL.__version__)
print('PIL Version:', PIL.VERSION)
# Out:
# Pillow Version: 6.2.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-7276f752efdb> in <module>
#       1 print('Pillow Version:', PIL.__version__)
# ----> 2 print('PIL Version:', PIL.VERSION)
#
# AttributeError: module 'PIL' has no attribute 'VERSION'

# %% [markdown]
# #### Classe para fazer a manipulação de imagens

# %%
from PIL import Image

# %% [markdown]
# #### Carregar um imagem a partir do disco

# %%
imagem = Image.open('./materiais-apoio-01/imagens/new-york.jpg')

# %% [markdown]
# #### Visualizando a imagem no console do Jupyter Lab

# %%
imagem
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=639x358 at 0x19DF7C15808>

# %% [markdown]
# #### Visualizando a imagem no SO

# %%
imagem.show()

# %% [markdown]
# #### Exibir as propriedades da imagem

# %% [markdown]
# **Imprimindo o formato da imagem**

# %%
print(imagem.format)
# Out:
# JPEG

# %% [markdown]
# **Imprimindo o canal do formato de pixel**

# %%
print(imagem.mode)
# Out:
# RGB

# %% [markdown]
# **Imprimindo as dimisões da imagem**

# %%
print(imagem.size)
# Out:
# (639, 358)

# %% [markdown]
# ### Pixel e Estrutura de Dados de Imagens

# %% [markdown]
# **Pixel** é a menor unidade de informação que compoe uma imagem digital.
#
# Em uma imagem RGB o pixel é representado por três números de **8 bits** associados com as cores **R,G e B** que correspondem as cores **Red (Vermelho)**, **Green (Verde)** e **Blue (Azul)** respectivamente.
#
# Como são números de 8 bits a faixa de valores é de **0 até 255**.

# %%
Image.open("./materiais-apoio-01/imagens/pixel-rgb.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=724x284 at 0x19DF7C62148>

# %% [markdown]
# A cor do Pixel será gerada a partir da combinação de cada um dos canais.
#
# Se a combinação de valores for 255 a cor do pixel será **branco**, se a combinação for 0, a cor do Pixel será **preto**.

# %%
![football](./materiais-apoio-01/imagens/rgb_gif.gif "rgb")
# Out:
# '[football]' não é reconhecido como um comando interno
# ou externo, um programa operável ou um arquivo em lotes.

# %% [markdown]
# #### Convertendo Imagens para arrays Numpy

# %% [markdown]
# ##### importando as bibliotecas para visualização das imagens

# %%
from matplotlib import image
from matplotlib import pyplot

# %% [markdown]
# **Carregando a imagem como um array Numpy**

# %%
data = image.imread('./materiais-apoio-01/imagens/new-york.jpg')

# %%
data
# Out:
# array([[[148, 188, 188],
#         [148, 188, 188],
#         [148, 188, 188],
#         ...,
#         [119, 145, 146],
#         [119, 145, 146],
#         [119, 145, 144]],
#
#        [[149, 189, 189],
#         [149, 189, 189],
#         [149, 189, 189],
#         ...,
#         [119, 145, 146],
#         [119, 145, 146],
#         [118, 144, 145]],
#
#        [[150, 190, 190],
#         [150, 190, 190],
#         [150, 190, 190],
#         ...,
#         [118, 144, 145],
#         [118, 144, 145],
#         [118, 144, 145]],
#
#        ...,
#
#        [[132, 137, 105],
#         [128, 135, 102],
#         [124, 131,  98],
#         ...,
#         [ 16,  22,  44],
#         [ 15,  27,  49],
#         [ 22,  39,  59]],
#
#        [[129, 134, 102],
#         [127, 134, 101],
#         [123, 130,  99],
#         ...,
#         [ 66,  64,  85],
#         [ 51,  53,  76],
#         [ 38,  46,  67]],
#
#        [[124, 129,  97],
#         [124, 131,  98],
#         [125, 132, 101],
#         ...,
#         [ 39,  30,  49],
#         [ 46,  41,  64],
#         [ 52,  52,  76]]], dtype=uint8)

# %% [markdown]
# **Imprimindo as propriedades do array de pixel**

# %%
data.dtype
# Out:
# dtype('uint8')

# %%
data.shape
# Out:
# (358, 639, 3)

# %%
data.max()
# Out:
# 255

# %%
data.min()
# Out:
# 0

# %% [markdown]
# **Exibindo o array de pixel como uma imagem**

# %%
pyplot.imshow(data)

# %% [markdown]
# **Convertendo o array de pixel em um objeto Image Pillow**

# %%
image2 = Image.fromarray(data)

# %% [markdown]
# **Verificando o tipo de objeto**

# %%
type(image2)
# Out:
# PIL.Image.Image

# %% [markdown]
# **Convertendo um objketo do tipo de imagem para array numpy**

# %%
from numpy import asarray

# %%
imagee = Image.open('./materiais-apoio-01/imagens/new-york.jpg')

# %% [markdown]
# ##### método asarray para realizar a conversão

# %%
data = asarray(image)

# %% [markdown]
# ##### imprimindo os atributos do array

# %%
print(data.dtype)
print(data.shape)
# Out:
# object
# ()

# %% [markdown]
# #### Salvando imagens em disco

# %% [markdown]
# **Salvando a imagem no formato PNG**

# %%
imagem.save('./minhas_imagens/new_york.png', format='PNG')

# %% [markdown]
# **Salvando a imagem no formato GIF**

# %%
imagem.save('./minhas_imagens/new_york.gif', format='GIF')

# %% [markdown]
# **Carregando a imagem e verificando o formato**

# %%
image3 = Image.open('./minhas_imagens/new_york.gif')

# %%
image3.format
# Out:
# 'GIF'

# %% [markdown]
# #### Convertendo imagens

# %% [markdown]
# ##### convertendo a imagem em escala de cinza

# %%
image_cinza = image3.convert(mode="L")

# %%
image_cinza
# Out:
# <PIL.Image.Image image mode=L size=639x358 at 0x19DF7CDF308>

# %% [markdown]
# **Salvando a imagem em disco**

# %%
image_cinza.save('./minhas_imagens/new_york_cinza.png', format='PNG')

# %% [markdown]
# ### Resize da imgem

# %% [markdown]
# **Verificando o tamanho da imagem com o atributo size**

# %%
print(imagem.size)
# Out:
# (639, 358)

# %%
imagem.thumbnail((100,100))

# %%
imagem
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x56 at 0x19DF7C15808>

# %% [markdown]
# ##### verificando as novas dimensões

# %%
print(imagem.size)
# Out:
# (639, 358)

# %% [markdown]
# ##### carregando novamente a imagem

# %%
imagem = Image.open("./materiais-apoio-01/imagens/new-york.jpg")

# %% [markdown]
# ##### resize a imagem ignorando o aspect ratio
# * Não liga para o proporção da imagem

# %%
image_resize = imagem.resize((200,200))

# %%
image_resize
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x19DFB2C24C8>

# %%
print(imagem.size)
# Out:
# (639, 358)

# %% [markdown]
# #### Invertendo Imagens (Flip)

# %%
vertical_image = imagem.transpose(Image.FLIP_LEFT_RIGHT)

# %%
vertical_image
# Out:
# <PIL.Image.Image image mode=RGB size=639x358 at 0x19DF9D49E88>

# %% [markdown]
# ##### Inversão horizontal

# %%
horizontal_imagem = imagem.transpose(Image.FLIP_TOP_BOTTOM)

# %%
horizontal_imagem
# Out:
# <PIL.Image.Image image mode=RGB size=639x358 at 0x19DFB34C8C8>

# %% [markdown]
# #### Girar Imagens (Rotate)

# %% [markdown]
# ##### carregando novamente a imagem

# %%
image = Image.open("./materiais-apoio-01/imagens/new-york.jpg")

# %% [markdown]
# ##### rotacionando a imagem em 45 graus

# %%
pyplot.imshow(image.rotate(45))

# %% [markdown]
# ##### rotacionando a imagem em 90 graus

# %%
pyplot.imshow(image.rotate(90))

# %% [markdown]
# #### Cortar Imagens (Crop)

# %% [markdown]
# ##### exibindo a imagem original

# %%
pyplot.imshow(image)

# %% [markdown]
# ##### exibindo o corte a partir das coordenadas especificadas - left, upper, right, and lower

# %%
pyplot.imshow(image.crop((100,100,200,200)))

# %% [markdown]
# #### Técnicas de pré-processamento aplicado a imagens

# %% [markdown]
# ##### normalizando valores de pixels

# %%
image = Image.open("./materiais-apoio-01/imagens/new-york.jpg")

# %% [markdown]
# **Convertendo a imagem em um array**

# %%
pixels = asarray(image)

# %% [markdown]
# **Verificando a faixa de valores entre 0 e 255**

# %%
print(f'DataType: {pixels.dtype}')
print(f'Min: {pixels.min()} - Máx: {pixels.max()}')
# Out:
# DataType: uint8
# Min: 0 - Máx: 255

# %% [markdown]
# **Convertendo os valores inteiros em float para realizar operação**

# %%
pixels = pixels.astype('float32')

# %% [markdown]
# **Normaliza a faixa de valores**

# %%
pixels /= pixels.max()

# %% [markdown]
# **Verificando a faixa de valores normalizada**

# %%
print(f'DataType: {pixels.dtype}')
print(f'Min: {pixels.min()} - Máx: {pixels.max()}')
# Out:
# DataType: float32
# Min: 0.0 - Máx: 1.0
